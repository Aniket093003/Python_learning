# %% [markdown]
# # Create a 1D array of size 5 using:
#
# # np.empty()
#
# # np.zeros()
#
# # np.ones()
# # Compare the outputs.

# %%
import numpy as np

# %%
print("random",np.empty(5,dtype=int))
print("zero",np.zeros(5,dtype=int))
print("ones",np.ones(5,dtype=int))
# Out:
# random [1 1 1 1 1]
# zero [0 0 0 0 0]
# ones [1 1 1 1 1]
